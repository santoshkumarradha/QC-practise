# %%
from qiskit import IBMQ, BasicAer
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
import matplotlib.pyplot as plt
import numpy as np
from math import pi
# %matplotlib inline

# %%
from algos import deutsch_jozsa,berstein_vazirani,simons,qft

# %%
deutsch_jozsa(n=2,u="const")
# Out:
# Simulator result
# 00 is observed in 1024 times
# U is Constant
# &lt;Figure size 695.413x264.88 with 1 Axes&gt;

# %%
berstein_vazirani(n=5,b='10111')
# Out:
# 10111 is observed in 1024 times and the result is 10111
# &lt;Figure size 996.849x445.48 with 1 Axes&gt;

# %%
simons('10')
# Out:
# b = 10
# 10 b-xor 00 = 0 (46.0%)
# 10 b-xor 01 = 0 (54.0%)
# &lt;Figure size 708.829x325.08 with 1 Axes&gt;

# %%
qft('1001',1)
# Out:
# &lt;Figure size 1551.63x325.08 with 1 Axes&gt;
# |1111&gt; - 78
# |1001&gt; - 55
# |0101&gt; - 67
# |0000&gt; - 79
# |1101&gt; - 60
# |1110&gt; - 69
# |0001&gt; - 62
# |1011&gt; - 64
# |1010&gt; - 66
# |1100&gt; - 54
# |1000&gt; - 52
# |0111&gt; - 51
# |0010&gt; - 69
# |0110&gt; - 62
# |0100&gt; - 66
# |0011&gt; - 70
